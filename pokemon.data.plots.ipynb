# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
sns.set(color_codes = True)

# %%
pokemon = pd.read_csv('pokemon_data.csv')

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 6  6              Charizard   Fire  Flying  78      84       78      109
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 6       85    100           1      False

# %%
pokemon.info()

# %%
g = sns.stripplot(data = pokemon, x = 'Legendary', y = 'Generation', hue = 'Type 2')

# %%
type2_flying = pokemon.loc[pokemon['Type 2'] == 'Flying']
type2_flying
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 6      6                  Charizard      Fire  Flying   78      84       78
# 8      6  CharizardMega Charizard Y      Fire  Flying   78     104       78
# 15    12                 Butterfree       Bug  Flying   60      45       50
# 20    16                     Pidgey    Normal  Flying   40      45       40
# 21    17                  Pidgeotto    Normal  Flying   63      60       55
# ..   ...                        ...       ...     ...  ...     ...      ...
# 730  662                Fletchinder      Fire  Flying   62      73       55
# 731  663                 Talonflame      Fire  Flying   78      81       71
# 734  666                   Vivillon       Bug  Flying   80      52       50
# 771  701                   Hawlucha  Fighting  Flying   78      92       75
# 793  717                    Yveltal      Dark  Flying  126     131       95
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
sns.pairplot(type2_flying[['Attack', 'Defense', 'Speed']])

# %%
speed_more_100 = pokemon.loc[pokemon['Speed'] > 99]
speed_more_100
# Out:
#        #                       Name    Type 1  Type 2  HP  Attack  Defense  \
# 6      6                  Charizard      Fire  Flying  78      84       78
# 7      6  CharizardMega Charizard X      Fire  Dragon  78     130      111
# 8      6  CharizardMega Charizard Y      Fire  Flying  78     104       78
# 19    15      BeedrillMega Beedrill       Bug  Poison  65     150       40
# 22    18                    Pidgeot    Normal  Flying  83      80       75
# ..   ...                        ...       ...     ...  ..     ...      ...
# 765  695                  Heliolisk  Electric  Normal  62      55       52
# 771  701                   Hawlucha  Fighting  Flying  78      92       75
# 772  702                    Dedenne  Electric   Fairy  67      58       57
# 791  715                    Noivern    Flying  Dragon  85      70       80
# 796  719        DiancieMega Diancie      Rock   Fairy  50     160      110
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
sns.regplot(data = speed_more_100, x = 'Defense', y = 'Speed')
# Out:
# <Axes: xlabel='Defense', ylabel='Speed'>
